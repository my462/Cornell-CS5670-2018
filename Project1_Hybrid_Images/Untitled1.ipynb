# %%
import numpy as np
img = np.random.rand(7,5,3)

# %%
img
# Out:
# array([[[ 0.56649078,  0.45561259,  0.71295014],
#         [ 0.66149533,  0.60651243,  0.71880702],
#         [ 0.90741871,  0.8623948 ,  0.54481306],
#         [ 0.48767635,  0.09136968,  0.93416219],
#         [ 0.35346621,  0.75771503,  0.13560999]],
#
#        [[ 0.3621501 ,  0.16277127,  0.432094  ],
#         [ 0.16639379,  0.98863932,  0.91210225],
#         [ 0.76949002,  0.66063012,  0.10926018],
#         [ 0.57168839,  0.2601485 ,  0.12783132],
#         [ 0.68079585,  0.59059519,  0.34928441]],
#
#        [[ 0.1068996 ,  0.79899709,  0.4135778 ],
#         [ 0.35928395,  0.1203769 ,  0.05254128],
#         [ 0.15725063,  0.95946708,  0.60987401],
#         [ 0.55313899,  0.67234315,  0.66927912],
#         [ 0.10599489,  0.28347836,  0.94917667]],
#
#        [[ 0.58982906,  0.90243076,  0.60954424],
#         [ 0.71902532,  0.99185588,  0.7343517 ],
#         [ 0.95521296,  0.43633945,  0.5006044 ],
#         [ 0.24126582,  0.7264597 ,  0.84375959],
# ...
